# %% [markdown]
# # Process OGC Web Feature Service
#
# This notebook uses an endpoint URL, passed either as an 'endpoint' parameter when the notebook is called, or assigned in cell 5.

# %% [markdown]
# #for some reason the env variable is not getting set when the book is first opened, have to set manually
# #WFS driver doesn't work
# #!set GDAL_DATA=E:\EPrograms\Anaconda\envs\py36\Library\share\gdal
# !set GDAL_DATA

# %%
# %%javascript
# //check if there is an endpoint parameter in the notebook call
#
# function getQueryStringValue (key)
# {
#     return unescape(window.location.search.replace(new RegExp("^(?:.*[&\\?]" + escape(key).replace(/[\.\+\*]/g, "\\$&") + "(?:\\=([^&]*))?)?.*$", "i"), "$1"));
# }
# IPython.notebook.kernel.execute("endpoint='".concat(getQueryStringValue("endpoint")).concat("'"));
# IPython.notebook.kernel.execute("full_notebook_url='" + window.location + "'");

# %%
import sys
try:
    from osgeo import ogr, gdal
except:
    sys.exit('ERROR: cannot find GDAL/OGR modules')
    
from ipywidgets import interact

import requests
import json
from pandas.io.json import json_normalize
maxfeatures=50000

#import numpy as np
#import pandas as pd
#import xmltodict
#from ipywidgets import interactive, fixed, interact_manual
#import ipywidgets as widgets

# %%
def the_envelope(geom):
    (minX, maxX, minY, maxY) = geom.GetEnvelope()
    # calculate a bounding box geometry for the given geometry argument
    # Create ring
    ring = ogr.Geometry(ogr.wkbLinearRing)
    ring.AddPoint(minX, minY)
    ring.AddPoint(maxX, minY)
    ring.AddPoint(maxX, maxY)
    ring.AddPoint(minX, maxY)
    ring.AddPoint(minX, minY)

    # Create polygon
    poly_envelope = ogr.Geometry(ogr.wkbPolygon)
    poly_envelope.AddGeometry(ring)
    return poly_envelope

# %%
def testurl(theurl):
    #try HEAD first in case the response document is big
    r = requests.head(theurl)
    if (r.status_code != requests.codes.ok):
        #check GET in case is an incomplete http implementation
        r = requests.get(theurl)
        if (r.status_code == requests.codes.ok):
            return True
        else:
            return False
    else:
        return True

# %%
url_partitioned = full_notebook_url.partition('ISOmetadata-ExtractDistributions.ipynb')
base_url = url_partitioned[0];

if(endpoint is not None and len(endpoint)>0):
    print('Got endpoint parameter:',endpoint)
else: 
    # some USGS ScienceBase Geoserver WFS endpoints:
    #endpoint='https://www.sciencebase.gov/catalogMaps/mapping/ows/5342c54be4b0aa151574a8dc'
    #endpoint='https://www.sciencebase.gov/catalogMaps/mapping/ows/5342c5fce4b0aa151574a8ed'
    #endpoint='https://www.sciencebase.gov/catalogMaps/mapping/ows/4f4e49cfe4b07f02db5da90e'

    # some NGDS end points
    endpoint='http://services.azgs.az.gov/arcgis/services/aasggeothermal/CAaqWellChemistry/MapServer/WFSServer'
    #endpoint='http://services.azgs.az.gov/arcgis/services/aasggeothermal/AZActiveFaults/MapServer/WFSServer'

    #EarthChem
    #endpoint='http://ecp.iedadata.org/wfs/ows?service=wfs'

    #smu thermal conductivity, geoserver
    #endpoint='http://geothermal.smu.edu:9000/geoserver/aasg-thermalconductivity/ows'

    #NOAA Watch/warning polygons
    #endpoint = 'https://idpgis.ncep.noaa.gov/arcgis/services/NWS_Forecasts_Guidance_Warnings/watch_warn_adv/MapServer/WFSServer'
    print('Assign endpoint:', endpoint)
# limit the number of features that will be processed
# Out:
# ('Got endpoint parameter:', 'http://services.azgs.az.gov/arcgis/services/NGDS/USPowerPlantFacilities/MapServer/WFSServer')

# %%
## Shapefile available?
driverName = "WFS"
# Set the driver (optional)
wfs_drv = ogr.GetDriverByName(driverName)

if wfs_drv is None:
    print ("%s driver not available.\n" % driverName)
else:
    print  ("%s driver IS available.\n" % driverName)
# Out:
# WFS driver IS available.

# %%
# !set GDAL_DATA=E:\EPrograms\Anaconda\Library\share\gdal
# !set GDAL_DATA

# %%
# Speeds up querying WFS capabilities for services with alot of layers
gdal.SetConfigOption('OGR_WFS_LOAD_MULTIPLE_LAYER_DEFN', 'NO')

# Set config for paging. Works on WFS 2.0 services and WFS 1.0 and 1.1 with some other services.
gdal.SetConfigOption('OGR_WFS_PAGING_ALLOWED', 'YES')
gdal.SetConfigOption('OGR_WFS_PAGE_SIZE', '10000')


#test that service is up with getcapabilities request

capurl=endpoint + '?service=wfs&request=getCapabilities'

if testurl(capurl):
    # Open the webservice
    wfs_ds = wfs_drv.Open('WFS:' + endpoint)
    #wfs_ds = wfs_drv.Open(endpoint + '?SERVICE=WFS&VERSION=1.1.0')
    if wfs_ds is None:
        print('ERROR: can not open WFS datasource')
else:
    print('ERROR: service not responding')

# %%
capurl
# Out:
# 'http://services.azgs.az.gov/arcgis/services/NGDS/USPowerPlantFacilities/MapServer/WFSServer?service=wfs&request=getCapabilities'

# %%
# iterate over available layers
for i in range(wfs_ds.GetLayerCount()):
    layer = wfs_ds.GetLayerByIndex(i)
    srs = layer.GetSpatialRef()
    print ('Layer: %s, Features: %s, SR: %s...' % (layer.GetName(), layer.GetFeatureCount(), srs.ExportToWkt()[0:50]))

    # iterate over features
    #fcount = 1
    #feat = layer.GetNextFeature()
    #while feat is not None:
    #    feat = layer.GetNextFeature()
    #    fcount = fcount + 1
        # do something more..
    #feat = None
    print ('feature count: ',layer.GetFeatureCount())
# Out:
# Layer: aasg:PowerPlantFacility, Features: 7263, SR: GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84"...
# ('feature count: ', 7263)

# %% [markdown]
# #gdal call to get the capabilities document
# caps=wfs_ds.GetLayerByName('WFSGetCapabilities')
# #print the number of feature types reported in the capabilities document
# print(caps.GetFeatureCount())
#
# for feat in caps:
#     jsonwrap= json.loads(feat.ExportToJson())
#
# capsxml=jsonwrap['properties']['content']
# capsjson=xmltodict.parse(capsxml)
# capsjson=json.dumps(capsjson, indent=2)
# #print(capsjson)

# %% [markdown]
# Want to let user pick the layer to work with.

# %%
feat_list={}
for i in range(wfs_ds.GetLayerCount()):
    layer = wfs_ds.GetLayerByIndex(i)
    feat_list[layer.GetName()] = layer.GetName()


def f(feat_menu):
    return feat_menu
# out = interact(f, feat_menu=nb_menu);
out = interact(f, feat_menu=feat_list.keys());

#print("interact out: ", out)
# Out:
# interactive(children=(Dropdown(description=u'feat_menu', options=('aasg:PowerPlantFacility',), value='aasg:Powâ€¦

# %%
# Get a specific layer

chosenlayer= feat_list[out.widget.result]
if len(chosenlayer)==0:
    chosenlayer=wfs_ds.GetLayerByIndex(1).GetName()

layer = wfs_ds.GetLayerByName(chosenlayer)

print('chosen layer:',chosenlayer)

if not layer:
    sys.exit('ERROR: can not find layer in service')
else:
    pass
# Out:
# ('chosen layer:', 'aasg:PowerPlantFacility')

# %%
layer.GetFeatureCount()
# Out:
# 7263

# %%
# %%time
count = 0
tdata = []

geometries=[]
if (layer.GetFeatureCount()>0):
    feat=layer.GetFeature(1)
#    print(feat)

    for feat in layer:
        thisgeom = feat.geometry().GetGeometryName()

        if (thisgeom not in geometries):
            geometries.append(thisgeom)
        #ExportToJson doesn't work with some geometries (e.g .MULTISURFACE(??), 
        # in that case, replace with bounding box     
        try:
            temp=feat.ExportToJson()
        except:
            msenvelope=the_envelope( feat.geometry())
            #print('BoundingBox: %s' % msenvelope)
            thenote = 'Replace '+ thisgeom + ' with bounding box'
            if (thenote not in geometries):
                geometries.append(thenote)
            feat.SetGeometry(msenvelope)
        tdata.append(json.loads(feat.ExportToJson()))
        #feat = layer.GetNextFeature()
        count = count + 1
        #avoid getting hung on very long responses, maxsfeatures set in imports cell at top of notebook
        if count > maxfeatures:
            break
feat = None
print (geometries)

#print (tdata)
dataframe=json_normalize(tdata)
print('Dataframe size:',dataframe.size)

#dataframe
print('done timed cell, %s features in result set' % count)
# Out:
# ['POINT']
# ('Dataframe size:', 67000)
# done timed cell, 1000 features in result set
# Wall time: 5.06 s

# %% [markdown]
# Problem with json_normalize:
# This appears to be a bug in the latest version of pandas: https://github.com/pandas-dev/pandas/issues/21158
# Running pandas '0.23.0', error arises due to condition case when null value occurs on the nesting level greater than 0. It seems to have been changed around two months ago that seems to have made it's way into 0.23.0 release two weeks ago:
#
# https://github.com/pandas-dev/pandas/commit/01882ba5b4c21b0caf2e6b9279fb01967aa5d650#diff-9c654764f5f21c8e9d58d9ebf14de86d
#
# When I use python verion 3.6.3 :: Anaconda Inc. and pandas version 0.20.3 I do not see this issue and json_normalize is able to work properly.
#
# 2018-06-28 SMR rolled pandas back to 0.20.3 in the py36 kernel env.

# %% [markdown]
# Now get a list of the attributes of the feature type

# %% [markdown]
#     #example function to get field definitions from gdal
#     #these are more informative than the pandas dataframe definitions
#     lyrDefn = layer.GetLayerDefn()
#     for i in range( lyrDefn.GetFieldCount() ):
#         fieldName =  lyrDefn.GetFieldDefn(i).GetName()
#         fieldTypeCode = lyrDefn.GetFieldDefn(i).GetType()
#         fieldType = lyrDefn.GetFieldDefn(i).GetFieldTypeName(fieldTypeCode)
#         fieldWidth = lyrDefn.GetFieldDefn(i).GetWidth()
#         GetPrecision = lyrDefn.GetFieldDefn(i).GetPrecision()
#
#         print (fieldName + " - " + fieldType+ " " + str(fieldWidth) + " " + str(GetPrecision))

# %% [markdown]
# Do some data summarization with pandas

# %% [markdown]
# #easy pandas way to get the field types
# #dataframe.dtypes

# %%
#for value in dataframe['properties.K_mgL']:
#    if value != None:
#        print (value)
lyrDefn = layer.GetLayerDefn()

for col in dataframe.columns:
    if (col.find('.')>-1):
        field=str(col.split('.')[1])
        #print('col: %s, field: %s' % (col, field))
        fielddef = lyrDefn.GetFieldDefn(lyrDefn.GetFieldIndex(field))
        if (fielddef is not None):
            fieldTypeCode = fielddef.GetType()
            fieldType = fielddef.GetFieldTypeName(fieldTypeCode)
            fieldWidth = fielddef.GetWidth()
            GetPrecision = fielddef.GetPrecision()       
            print (field + " - " + fieldType+ " " + str(fieldWidth) + " " + str(GetPrecision))
        else:
            print(field + ' has no ogr definition')

            
def findfieldtype(pcol):
    if (pcol.find('.')>-1):
        field=str(pcol.split('.')[1])
    else:
        field=str(pcol)
    fielddef = lyrDefn.GetFieldDefn(lyrDefn.GetFieldIndex(field))
    if (fielddef is not None):
        thetype= fielddef.GetFieldTypeName(fielddef.GetType())
    else:
        thetype='xxxx'
    return thetype
# Out:
# coordinates has no ogr definition
# type has no ogr definition
# Capacity_MW - Real 0 0
# County - String 255 0
# EMailAddress - String 255 0
# FERC_Cogeneration_Docket_Number - String 255 0
# FERC_Cogeneration_Status - String 255 0
# FERC_Exempt_Wholesale_Generator_Docket_Number - String 255 0
# FERC_Exempt_Wholesale_Generator_Status - String 255 0
# FERC_Small_Power_Producer_Docket_Number - String 255 0
# FERC_Small_Power_Producer_Status - String 255 0
# FacilityContact - String 255 0
# FacilityURI - String 255 0
# Flow_gpm - Real 0 0
# FluidTemperature_C - Real 0 0
# Grid_Voltage__kV_ - String 255 0
# ISO_RTO - String 255 0
# ISO_RTO_Code - String 255 0
# Label - String 255 0
# LatDegree - Real 0 0
# LocationKeyword - String 255 0
# LocationUncertaintyCode - String 255 0
# LocationUncertaintyRadius - Real 0 0
# LocationUncertaintyStatement - String 255 0
# LongDegree - Real 0 0
# MetadataURI - String 255 0
# NERC_Region - String 255 0
# Name_of_Water_Source - String 255 0
# Notes - String 255 0
# OBJECTID - Integer 0 0
# OWNERSTATE - String 255 0
# OWNERTRANSID - String 255 0
# OperationalDate - String 0 0
# Operator - String 255 0
# OtherID - String 255 0
# Owner - String 255 0
# PLSS_Meridians - String 255 0
# Phone - String 255 0
# PlantName - String 255 0
# PlantType - String 255 0
# PostalAddress - String 255 0
# Range - String 255 0
# Regulatory_Status - String 255 0
# RelatedResource - String 255 0
# SERVICE_AREA - String 255 0
# SRS - String 255 0
# SectionPart - String 255 0
# Section_ - String 255 0
# Sector - String 255 0
# Sector_Name - String 255 0
# Source - String 255 0
# State - String 255 0
# Status - String 255 0
# StatusDate - String 0 0
# Township - String 255 0
# Transmission_or_Distribution_System_Owner - String 255 0
# Transmission_or_Distribution_System_Owner_ID - String 255 0
# Transmission_or_Distribution_System_Owner_State - String 255 0
# UTMDatumZone - String 255 0
# UTM_E - Real 0 0
# UTM_N - Real 0 0
# UpdateTimeStamp - String 0 0
# UseApplication - String 255 0
# Zip - String 255 0
# gml_id - String 0 0

# %%
print('%s features analyzed.' % len(dataframe.index))

print('Geometres found: %s' % geometries)

for col in dataframe.columns:
    #print(col)
    if (col.find('.')>-1):
        colname=str(col.split('.')[1])
    else:
        colname=str(col)
        
    if (dataframe[col].count() > 0) and  (dataframe[col].dtype=='float64'):
        mean=dataframe[col].mean()
        max=dataframe[col].max()
        min=dataframe[col].min()
        print('field:%s, count:%s, mean:%s; max:%s; min:%s \n' 
              % (colname, dataframe[col].count(), "{:.2f}".format(mean), 
                 "{:.2f}".format(max), "{:.2f}".format(min)))
    
    if (dataframe[col].count() > 0) and  (findfieldtype(col).find('Integer')>-1):
        max=dataframe[col].max()
        min=dataframe[col].min()
        print('field:%s, count:%s: max:%s; min:%s \n' 
              % (colname, dataframe[col].count(),  
                 "{:.2f}".format(max), "{:.2f}".format(min)))
    
    if (dataframe[col].count() > 0) and  (findfieldtype(col)=='String'):
        # and  (type(dataframe[col][1])=='str')
        #for item in dataframe[col].unique():
        #    print (item)
        #print (type(dataframe[col][1]))
        if len(dataframe.index)==len(dataframe[col].unique()):
            print(colname + ' is a text field, all values are unique')

        elif (len(dataframe[col].unique()) > 50):
            print(colname + ' appears to be a free text field, there are ' + str(len(dataframe[col].unique())) + ' unique values.' )

        else:
            print (colname +' has '+ str(len(dataframe[col].unique())) + ' unique values.') 
            print(dataframe[col].value_counts())
            
        print('\n')
 
emptyfields = []
print('\nThe following fields contain no data:')
for col in dataframe.columns:            
    if (dataframe[col].count() == 0):
        emptyfields.append(str(col.split('.')[1]))       
print(emptyfields)
# Out:
# 1000 features analyzed.
# Geometres found: ['POINT']
# field:Capacity_MW, count:1000, mean:-9999.00; max:-9999.00; min:-9999.00
#
# County appears to be a free text field, there are 299 unique values.
#
#
# FERC_Cogeneration_Docket_Number has 24 unique values.
# 85-698-000                                           1
# 8564000                                              1
# 96-114-000;  96-114-001;  96-114-002;  96-114-003    1
# 01-81-000                                            1
# 86-663-000                                           1
# 89-116-000                                           1
# QF10-431-000                                         1
# 82-15-000                                            1
# 90-32-001                                            1
# 90-178-001                                           1
# 92-91-001                                            1
# 91-221-000                                           1
# 87-83-001; '99-54-00                                 1
# 01-76-001                                            1
# 05-36-000                                            1
# 81-1-000                                             1
# 86-380-000                                           1
# 90-123-000                                           1
# 94-142-000                                           1
# 89-45-000                                            1
# 83-158-000                                           1
# 83,306,000                                           1
# 91-162-000                                           1
# Name: properties.FERC_Cogeneration_Docket_Number, dtype: int64
#
#
# FERC_Cogeneration_Status has 3 unique values.
# N    780
# Y     23
# Name: properties.FERC_Cogeneration_Status, dtype: int64
#
#
# FERC_Exempt_Wholesale_Generator_Docket_Number appears to be a free text field, there are 62 unique values.
#
#
# FERC_Exempt_Wholesale_Generator_Status has 3 unique values.
# N    717
# Y     86
# Name: properties.FERC_Exempt_Wholesale_Generator_Status, dtype: int64
#
#
# FERC_Small_Power_Producer_Docket_Number appears to be a free text field, there are 111 unique values.
#
#
# FERC_Small_Power_Producer_Status has 3 unique values.
# N    692
# Y    111
# Name: properties.FERC_Small_Power_Producer_Status, dtype: int64
#
#
# FacilityContact has 1 unique values.
# Missing    1000
# Name: properties.FacilityContact, dtype: int64
#
#
# FacilityURI is a text field, all values are unique
#
#
# Grid_Voltage__kV_ has 46 unique values.
# 115      39
# 12.47    27
# 34.5     26
# 69       25
# 230      23
# 12.5     16
# 138      16
# 13.47    16
# 4.16     13
# 13.8     12
# 13       12
# 46        7
# 100       5
# 14.4      5
# 2.4       5
# 23        5
# 500       4
# 7.2       4
# 345       4
# 24.9      4
# 12.4      3
# 25        3
# 765       3
# 13.2      2
# 67        2
# 41.6      2
# 12        2
# 57        2
# 4         2
# 2.5       1
# 24        1
# 32.3      1
# 20        1
# 4.3       1
# 144       1
# 12.48     1
# 33        1
# 0.48      1
# 120       1
# 34        1
# 240       1
# 480       1
# 24.8      1
# 50        1
# 150       1
# Name: properties.Grid_Voltage__kV_, dtype: int64
#
#
# ISO_RTO has 3 unique values.
# N    277
# Y    180
# Name: properties.ISO_RTO, dtype: int64
#
#
# ISO_RTO_Code has 5 unique values.
# MISO     108
# ISONE     53
# NYISO     18
# NBSO       1
# Name: properties.ISO_RTO_Code, dtype: int64
#
#
# Label appears to be a free text field, there are 990 unique values.
#
#
# field:LatDegree, count:1000, mean:48.09; max:71.88; min:44.34
#
# LocationUncertaintyStatement has 1 unique values.
# Missing    1000
# Name: properties.LocationUncertaintyStatement, dtype: int64
#
#
# field:LongDegree, count:1000, mean:-104.64; max:-41.77; min:-171.74
#
# MetadataURI has 1 unique values.
# http://repository.stategeothermaldata.org/repository/resource/c3efd9b7ecd1a2d149148b12471ffd76/    1000
# Name: properties.MetadataURI, dtype: int64
#
#
# NERC_Region has 10 unique values.
# WECC    310
# MRO     281
# NPCC    179
# ASCC    131
# RFC      51
# MAPP     28
# MAIN      9
# ECAR      4
# SPP       1
# Name: properties.NERC_Region, dtype: int64
#
#
# Name_of_Water_Source appears to be a free text field, there are 294 unique values.
#
#
# Notes has 1 unique values.
# Missing    1000
# Name: properties.Notes, dtype: int64
#
#
# field:OBJECTID, count:1000: max:1000.00; min:1.00
#
# OWNERSTATE has 19 unique values.
# AK    114
# MN     83
# WA     77
# OR     76
# WI     58
# ME     49
# NY     32
# MI     30
# ND     29
# VT     18
# MT     16
# SD      9
# CO      8
# ID      6
# NH      4
# MA      1
# OH      1
# WY      1
# Name: properties.OWNERSTATE, dtype: int64
#
#
# OWNERTRANSID appears to be a free text field, there are 137 unique values.
#
#
# OperationalDate has 1 unique values.
# 1901-01-01T00:00:00    1000
# Name: properties.OperationalDate, dtype: int64
#
#
# OtherID appears to be a free text field, there are 459 unique values.
#
#
# Owner has 1 unique values.
# Missing    1000
# Name: properties.Owner, dtype: int64
#
#
# PlantName appears to be a free text field, there are 990 unique values.
#
#
# PlantType has 1 unique values.
# Missing    1000
# Name: properties.PlantType, dtype: int64
#
#
# PostalAddress appears to be a free text field, there are 793 unique values.
#
#
# Regulatory_Status has 3 unique values.
# RE    500
# NR    392
# Name: properties.Regulatory_Status, dtype: int64
#
#
# SERVICE_AREA has 40 unique values.
# Avista Corp                        6
# Northern States Power Co           6
# Bonneville Power Admin             6
# NorthWestern Energy                6
# Niagara Mohawk Power Corp          6
# Central Maine Power Co             6
# PacifiCorp                         5
# Bangor Hydro-Electric Co           5
# Wisconsin Public Service Corp      4
# Puget Sound Energy Inc             3
# Golden Valley Electric Assn Inc    3
# Consumers Energy Company           3
# Homer Electric Assn Inc            2
# Otter Tail Power Co                2
# Northwestern Wisconsin Elec Co     2
# Minnesota Power Inc                2
# Nodak Electric Coop Inc            2
# Seattle City of                    2
# Consumers Energy Co                1
# Wisconsin Public Power Inc Sys     1
# Wasco Electric Coop, Inc           1
# Other                              1
# Maine Public Service Co            1
# Idaho Power Co                     1
# Franklin Electric Light Co Inc     1
# Alpena Power Co                    1
# PUD No 1 of Klickitat County       1
# Eastern Maine Electric Coop        1
# Oregon Trail El Cons Coop, Inc     1
# Northwestern Electric Coop Inc     1
# North Central Power Co, Inc        1
# PUD No 1 of Mason County           1
# Wolverine Pwr Supply Coop Inc      1
# New York State Elec & Gas Corp     1
# Unalaska City of                   1
# Renville-Sibley Coop Pwr Assn      1
# Wisconsin Electric Power Co        1
# East Grand Forks City of           1
#                                    1
# Name: properties.SERVICE_AREA, dtype: int64
#
#
# SRS has 1 unique values.
# EPSG:4326    1000
# Name: properties.SRS, dtype: int64
#
#
# Sector has 8 unique values.
# 1    337
# 2    195
# 7     35
# 4     12
# 6      9
# 3      9
# 5      6
# Name: properties.Sector, dtype: int64
#
#
# Sector_Name has 11 unique values.
# Electric Utility      337
# IPP                   107
# IPP Non-CHP            88
# Industrial             26
# Industrial CHP         14
# IPP CHP                 9
# Commercial Non-CHP      7
# Commercial              6
# Commercial CHP          5
# Industrial Non-CHP      4
# Name: properties.Sector_Name, dtype: int64
#
#
# Source has 1 unique values.
# The U.S. Energy Information Administration (EIA) Application Programming Interface (API) at http://www.eia.gov/beta/api/index.cfm; also see EIA web map application at http://www.eia.gov/state/.    1000
# Name: properties.Source, dtype: int64
#
#
# State has 17 unique values.
# WA    141
# AK    137
# MN    136
# OR     95
# WI     93
# ME     81
# MI     66
# MT     53
# NY     50
# ND     49
# VT     30
# SD     22
# ID     18
# NH     11
# WY     10
# MA      7
# TX      1
# Name: properties.State, dtype: int64
#
#
# Status has 1 unique values.
# Missing    1000
# Name: properties.Status, dtype: int64
#
#
# Transmission_or_Distribution_System_Owner appears to be a free text field, there are 177 unique values.
#
#
# Transmission_or_Distribution_System_Owner_ID appears to be a free text field, there are 110 unique values.
#
#
# Transmission_or_Distribution_System_Owner_State has 16 unique values.
# AK    116
# OR     38
# MN     35
# WA     28
# WI     16
# MT     14
# ME     13
# NY     10
# MA      6
# VT      6
# ND      6
# NH      5
# MI      4
# ID      4
# SD      1
# Name: properties.Transmission_or_Distribution_System_Owner_State, dtype: int64
# UpdateTimeStamp has 1 unique values.
# 2014-04-28T00:00:00    1000
# Name: properties.UpdateTimeStamp, dtype: int64
#
#
# UseApplication has 25 unique values.
# 22        883
# 322122     39
# 322        15
# 321        12
# 311        11
# 611        10
# 32411       3
# 32213       3
# 622         3
# 518         3
# 562212      2
# 92          2
# 2213        2
# 325311      1
# 522         1
# 514         1
# 326         1
# 713         1
# 323         1
# 928         1
# 331         1
# 514199      1
# 335         1
# 211         1
# 327         1
# Name: properties.UseApplication, dtype: int64
#
#
# Zip appears to be a free text field, there are 654 unique values.
#
#
# gml_id is a text field, all values are unique
#
#
#
# The following fields contain no data:
# ['EMailAddress', 'Flow_gpm', 'FluidTemperature_C', 'LocationKeyword', 'LocationUncertaintyCode', 'LocationUncertaintyRadius', 'Operator', 'PLSS_Meridians', 'Phone', 'Range', 'RelatedResource', 'SectionPart', 'Section_', 'StatusDate', 'Township', 'UTMDatumZone', 'UTM_E', 'UTM_N']

# %%
 dataframe.describe()
# Out:
#                 id  properties.Capacity_MW  properties.LatDegree  \
# count  1000.000000                  1000.0           1000.000000
# mean    500.500000                 -9999.0             48.088016
# std     288.819436                     0.0              5.882011
# min       1.000000                 -9999.0             44.335600
# 25%     250.750000                 -9999.0             44.887209
# 50%     500.500000                 -9999.0             45.803750
# 75%     750.250000                 -9999.0             47.532153
# max    1000.000000                 -9999.0             71.878611
#
#        properties.LongDegree  properties.OBJECTID
# count            1000.000000          1000.000000
# mean             -104.642541           500.500000
# std                25.203708           288.819436
# min              -171.737500             1.000000
# 25%              -121.129459           250.750000
# 50%               -98.173059           500.500000
# 75%               -88.127505           750.250000
# max               -41.766389          1000.000000
